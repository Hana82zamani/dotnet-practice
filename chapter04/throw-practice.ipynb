// %%
static void Withdraw(decimal balance, decimal amount)
{
    ArgumentOutOfRangeException.ThrowIfNegativeOrZero(amount);
if (balance < amount)
    {
        throw new InvalidOperationException("Insufficient balance");

    }

    Console.WriteLine("Withdrawal successful");

}Withdraw(100,150);
// Out:
// System.InvalidOperationException: Insufficient balance
//    at Submission#6.Withdraw(Decimal balance, Decimal amount)
//    at Submission#6.<<Initialize>>d__0.MoveNext()
// --- End of stack trace from previous location ---
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)
//    at Submission#6.Withdraw(Decimal balance, Decimal amount)
//    at Submission#6.<<Initialize>>d__0.MoveNext()
// --- End of stack trace from previous location ---
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
static void AddProduct(string productName, decimal price)
{
ArgumentNullException.ThrowIfNullOrEmpty(productName);

ArgumentOutOfRangeException.ThrowIfNegativeOrZero(price);
    if (100000 < price)
    {
        
throw new InvalidOperationException("price is over than 100,000$");
    }
    Console.WriteLine("Product added successfully");
}
AddProduct("Laptop", 50000);
// Out:
// Product added successfully

// %%
static void CreateAccount(string username, string password, int age)
{
ArgumentNullException.ThrowIfNullOrEmpty(username);

ArgumentNullException.ThrowIfNullOrEmpty(password);

if (password.Length < 8)
    {
        throw new ArgumentException("Password must be at least 8 characters.");
    }

    ArgumentOutOfRangeException.ThrowIfNegativeOrZero(age);
    if (age < 18)
    {
        throw new InvalidOperationException("User must be at least 18 years old.");
    }
Console.WriteLine("Account created successfully");

}
CreateAccount("hana","hanazamani",22);
// Out:
// Account created successfully

// %%
static void ProcessPayment(decimal amount)
{
    ArgumentOutOfRangeException.ThrowIfNegativeOrZero(amount);
    if (amount > 1000)
    {
        throw new InvalidOperationException("Payment limit exceeded.");
    }

}
static void Checkout()
{
    try
    {
        ProcessPayment(2000);
    }
    catch(Exception ex)
    {
    Console.WriteLine( ex.Message);
        
        throw;
    }
}
