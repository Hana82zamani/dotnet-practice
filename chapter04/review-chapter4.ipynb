// %%
static void CalculateDiscount(decimal price , int percent)
{
    decimal discount = price * percent / 100;
}

Console.WriteLine(CalculateDiscount(2000 , 25););
// Out:
// (6,19): error CS0103: The name 'discount' does not exist in the current context
// Error: compilation error
